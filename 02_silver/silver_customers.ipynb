# %%
bronze_path = "abfss://bronze@retailstorage017.dfs.core.windows.net/customers"

df_bronze = spark.read.format("delta").load(bronze_path)
df_bronze.show()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.createScope("adls-secrets")
